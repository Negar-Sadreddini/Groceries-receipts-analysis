# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
groceries = pd.read_csv(r'C:\Users\negar\Desktop\Datasets for Python Programming\Groceries_dataset.csv')

# %%
groceries['Date'] = pd.to_datetime(groceries['Date'], format='%d-%m-%Y')
groceries = groceries.sort_values('Date')
groceries.index = list(range(0,len(groceries)))

# %%
print('The number of customers is',groceries['Member_number'].nunique())
print('The number of goods is',groceries['itemDescription'].nunique())
# Out:
# The number of customers is 3898
# The number of goods is 167

# %%
goods = set(list(groceries['itemDescription']))
# We survey on goods that have been bought at least 50 times and see the frequency of it
good_freq = {}
for good in goods:
    if list(groceries['itemDescription']).count(good) >= 50 : 
        good_freq[good] = list(groceries['itemDescription']).count(good)

# %%
sorted_good_freq = sorted(list(good_freq.items()) , key = lambda x: x[1] , reverse = True )

# %%
# Now we want to extract each receipt seperately. First we extract each customers all time receipts
customer_based = groceries.groupby(['Member_number','Date'])

# %%
receipts = []

for unkn in customer_based.groups:
    sub = []
    for num in customer_based.groups[unkn]:    
        sub.append(groceries.iloc[num]['itemDescription'])
    receipts.append(sub)

receipts = sorted(receipts,key=len)

# %%
two_items = list(filter(lambda x: len(x)==2,receipts))
two_items = sorted(two_items , key= lambda x : (x[0],x[1]) )
# two_items is a list containing all the receipts with only two items

# %%
more_than_two_items = list(filter(lambda x: len(x)!=2,receipts))
more_than_two_items = sorted(more_than_two_items , key= lambda x : (x[0],x[1]) )
# more_than_two_items is a list containing all the receipts with more than two items

# %%
for idx in range(len(two_items)):
    for num in range(idx,len(two_items)):
        if set(two_items[num]) == set(two_items[idx]):
            two_items[num] = two_items[idx]
# This is for unifying the same receipts with differect item positions

# %%
freq_tgthr = {}
for receipt in two_items:
    c = 0
    for goods in receipts:
        if receipt[0] != receipt[1]:
            if receipt[0] in goods:
                if receipt[1] in goods:
                    c += 1
    #print(receipt[0],receipt[1])
                    freq_tgthr[str(receipt[0].capitalize()+'  and  '+str(receipt[1].capitalize()))]= c

#freq_tgthr = sorted(freq_tgthr, key = value , reverse = True )
{k: v for k, v in sorted(freq_tgthr.items(), key = lambda item: item[1] , reverse=True)}

# The final results is a dictionary that shows us which items have been bought together more frequently!!!
# Out:
# {'Other vegetables  and  Whole milk': 222,
#  'Rolls/buns  and  Whole milk': 209,
#  'Soda  and  Whole milk': 174,
#  'Whole milk  and  Yogurt': 167,
#  'Other vegetables  and  Rolls/buns': 158,
#  'Other vegetables  and  Soda': 145,
#  'Sausage  and  Whole milk': 134,
#  'Tropical fruit  and  Whole milk': 123,
#  'Other vegetables  and  Yogurt': 121,
#  'Rolls/buns  and  Soda': 121,
#  'Rolls/buns  and  Yogurt': 117,
#  'Root vegetables  and  Whole milk': 113,
#  'Bottled beer  and  Whole milk': 107,
#  'Bottled water  and  Whole milk': 107,
#  'Citrus fruit  and  Whole milk': 107,
#  'Pip fruit  and  Whole milk': 99,
#  'Pastry  and  Whole milk': 97,
#  'Shopping bags  and  Whole milk': 95,
#  'Other vegetables  and  Tropical fruit': 94,
#  'Rolls/buns  and  Tropical fruit': 91,
#  'Canned beer  and  Whole milk': 90,
#  'Other vegetables  and  Sausage': 90,
#  'Sausage  and  Soda': 89,
#  'Soda  and  Yogurt': 87,
#  'Rolls/buns  and  Root vegetables': 86,
#  'Sausage  and  Yogurt': 86,
#  'Newspapers  and  Whole milk': 84,
#  'Bottled water  and  Other vegetables': 82,
#  'Soda  and  Tropical fruit': 81,
#  'Rolls/buns  and  Sausage': 80,
#  'Domestic eggs  and  Whole milk': 79,
#  'Frankfurter  and  Whole milk': 79,
#  'Other vegetables  and  Root vegetables': 79,
#  'Root vegetables  and  Soda': 79,
#  'Tropical fruit  and  Yogurt': 78,
#  'Frankfurter  and  Other vegetables': 77,
#  'Pork  and  Whole milk': 75,
#  'Other vegetables  and  Pip fruit': 74,
#  'Other vegetables  and  Shopping bags': 74,
#  'Pip fruit  and  Rolls/buns': 74,
#  'Bottled water  and  Soda': 72,
#  'Citrus fruit  and  Other vegetables': 72,
#  'Rolls/buns  and  Shopping bags': 71,
#  'Beef  and  Whole milk': 70,
#  'Bottled beer  and  Other vegetables': 70,
#  'Bottled water  and  Rolls/buns': 70,
#  'Butter  and  Whole milk': 70,
#  'Citrus fruit  and  Rolls/buns': 70,
#  'Citrus fruit  and  Yogurt': 69,
#  'Whipped/sour cream  and  Whole milk': 69,
#  'Brown bread  and  Whole milk': 67,
#  'Fruit/vegetable juice  and  Whole milk': 66,
#  'Shopping bags  and  Soda': 66,
#  'Root vegetables  and  Yogurt': 64,
#  'Canned beer  and  Rolls/buns': 63,
#  'Curd  and  Whole milk': 62,
#  'Other vegetables  and  Whipped/sour cream': 62,
#  'Margarine  and  Whole milk': 61,
#  'Pastry  and  Soda': 61,
#  'Bottled beer  and  Rolls/buns': 60,
#  'Canned beer  and  Other vegetables': 60,
#  'Other vegetables  and  Pork': 59,
#  'Pastry  and  Rolls/buns': 59,
#  'Pip fruit  and  Soda': 59,
#  'Canned beer  and  Yogurt': 58,
#  'Bottled water  and  Yogurt': 57,
#  'Coffee  and  Whole milk': 57,
#  'Frozen vegetables  and  Whole milk': 57,
#  'Citrus fruit  and  Soda': 56,
#  'Fruit/vegetable juice  and  Rolls/buns': 56,
#  'Frankfurter  and  Rolls/buns': 55,
#  'Newspapers  and  Other vegetables': 55,
#  'Other vegetables  and  Pastry': 55,
#  'Root vegetables  and  Tropical fruit': 55,
#  'Pastry  and  Yogurt': 54,
#  'Pip fruit  and  Yogurt': 54,
#  'Bottled water  and  Tropical fruit': 53,
#  'Curd  and  Other vegetables': 53,
#  'Domestic eggs  and  Other vegetables': 53,
#  'Shopping bags  and  Yogurt': 53,
#  'Bottled water  and  Root vegetables': 52,
#  'Bottled beer  and  Yogurt': 51,
#  'Chicken  and  Whole milk': 51,
#  'Domestic eggs  and  Rolls/buns': 51,
#  'Pork  and  Rolls/buns': 51,
#  'Soda  and  Whipped/sour cream': 51,
#  'Bottled beer  and  Sausage': 50,
#  'Brown bread  and  Rolls/buns': 50,
#  'Root vegetables  and  Sausage': 50,
#  'Root vegetables  and  Shopping bags': 50,
#  'Margarine  and  Other vegetables': 48,
#  'Pastry  and  Sausage': 48,
#  'Bottled water  and  Sausage': 47,
#  'Butter  and  Soda': 47,
#  'Canned beer  and  Soda': 47,
#  'Frozen vegetables  and  Other vegetables': 47,
#  'White bread  and  Whole milk': 47,
#  'Brown bread  and  Other vegetables': 46,
#  'Frankfurter  and  Soda': 46,
#  'Hamburger meat  and  Whole milk': 46,
#  'Pork  and  Yogurt': 46,
#  'Sausage  and  Tropical fruit': 46,
#  'Margarine  and  Rolls/buns': 45,
#  'Newspapers  and  Rolls/buns': 45,
#  'Pork  and  Soda': 45,
#  'Bottled beer  and  Soda': 44,
#  'Chocolate  and  Whole milk': 44,
#  'Curd  and  Sausage': 44,
#  'Fruit/vegetable juice  and  Other vegetables': 44,
#  'Onions  and  Whole milk': 44,
#  'Rolls/buns  and  Whipped/sour cream': 44,
#  'Whipped/sour cream  and  Yogurt': 44,
#  'Bottled water  and  Pastry': 43,
#  'Brown bread  and  Soda': 43,
#  'Butter  and  Other vegetables': 43,
#  'Butter  and  Rolls/buns': 43,
#  'Chicken  and  Rolls/buns': 43,
#  'Citrus fruit  and  Tropical fruit': 43,
#  'Cream cheese   and  Whole milk': 43,
#  'Newspapers  and  Yogurt': 43,
#  'Pastry  and  Root vegetables': 43,
#  'Beef  and  Other vegetables': 42,
#  'Chocolate  and  Rolls/buns': 42,
#  'Curd  and  Soda': 42,
#  'Pastry  and  Tropical fruit': 42,
#  'Curd  and  Rolls/buns': 41,
#  'Frozen vegetables  and  Rolls/buns': 41,
#  'Ham  and  Whole milk': 41,
#  'Shopping bags  and  Tropical fruit': 41,
#  'Berries  and  Other vegetables': 40,
#  'Pip fruit  and  Root vegetables': 40,
#  'Bottled water  and  Citrus fruit': 39,
#  'Coffee  and  Other vegetables': 39,
#  'Margarine  and  Soda': 39,
#  'Other vegetables  and  White bread': 39,
#  'Waffles  and  Whole milk': 39,
#  'Uht-milk  and  Whole milk': 38,
#  'Bottled beer  and  Bottled water': 38,
#  'Bottled beer  and  Tropical fruit': 38,
#  'Canned beer  and  Tropical fruit': 38,
#  'Domestic eggs  and  Soda': 38,
#  'Frankfurter  and  Yogurt': 38,
#  'Newspapers  and  Root vegetables': 38,
#  'Bottled beer  and  Root vegetables': 37,
#  'Canned beer  and  Sausage': 37,
#  'Coffee  and  Soda': 37,
#  'Root vegetables  and  Whipped/sour cream': 37,
#  'Sugar  and  Whole milk': 37,
#  'Tropical fruit  and  Whipped/sour cream': 37,
#  'Brown bread  and  Canned beer': 36,
#  'Coffee  and  Rolls/buns': 36,
#  'Dessert  and  Whole milk': 36,
#  'Long life bakery product  and  Whole milk': 36,
#  'Napkins  and  Whole milk': 36,
#  'Brown bread  and  Yogurt': 35,
#  'Newspapers  and  Soda': 35,
#  'Berries  and  Whole milk': 34,
#  'Curd  and  Yogurt': 34,
#  'Beef  and  Yogurt': 33,
#  'Bottled water  and  Frankfurter': 33,
#  'Butter  and  Yogurt': 33,
#  'Chicken  and  Other vegetables': 33,
#  'Citrus fruit  and  Root vegetables': 33,
#  'Frankfurter  and  Root vegetables': 33,
#  'Fruit/vegetable juice  and  Yogurt': 33,
#  'Hamburger meat  and  Other vegetables': 33,
#  'Meat  and  Whole milk': 33,
#  'Other vegetables  and  Salty snack': 33,
#  'Pastry  and  Pip fruit': 33,
#  'Uht-milk  and  Other vegetables': 32,
#  'Bottled water  and  Domestic eggs': 32,
#  'Candy  and  Whole milk': 32,
#  'Chicken  and  Soda': 32,
#  'Citrus fruit  and  Pastry': 32,
#  'Cream cheese   and  Other vegetables': 32,
#  'Domestic eggs  and  Tropical fruit': 32,
#  'Frozen meals  and  Other vegetables': 32,
#  'Frozen vegetables  and  Root vegetables': 32,
#  'Fruit/vegetable juice  and  Soda': 32,
#  'Fruit/vegetable juice  and  Tropical fruit': 32,
#  'Margarine  and  Yogurt': 32,
#  'Meat  and  Other vegetables': 32,
#  'Napkins  and  Other vegetables': 32,
#  'Pip fruit  and  Sausage': 32,
#  'Rolls/buns  and  White bread': 32,
#  'Sausage  and  Whipped/sour cream': 32,
#  'Bottled beer  and  Pastry': 31,
#  'Canned beer  and  Root vegetables': 31,
#  'Citrus fruit  and  Whipped/sour cream': 31,
#  'Coffee  and  Yogurt': 31,
#  'Dessert  and  Other vegetables': 31,
#  'Domestic eggs  and  Yogurt': 31,
#  'Frozen vegetables  and  Sausage': 31,
#  'Frozen vegetables  and  Yogurt': 31,
#  'Pip fruit  and  Tropical fruit': 31,
#  'Bottled water  and  Pip fruit': 30,
#  'Bottled water  and  Shopping bags': 30,
#  'Brown bread  and  Pastry': 30,
#  'Butter  and  Root vegetables': 30,
#  'Coffee  and  Root vegetables': 30,
#  'Dessert  and  Rolls/buns': 30,
#  'Domestic eggs  and  Root vegetables': 30,
#  'Frozen vegetables  and  Soda': 30,
#  'Newspapers  and  Pastry': 30,
#  'Beverages  and  Whole milk': 29,
#  'Bottled water  and  Curd': 29,
#  'Butter  and  Citrus fruit': 29,
#  'Butter  and  Sausage': 29,
#  'Frozen meals  and  Whole milk': 29,
#  'Grapes  and  Whole milk': 29,
#  'Hamburger meat  and  Rolls/buns': 29,
#  'Ice cream  and  Whole milk': 29,
#  'Margarine  and  Root vegetables': 29,
#  'Oil  and  Whole milk': 29,
#  'Rolls/buns  and  Salty snack': 29,
#  'Salty snack  and  Whole milk': 29,
#  'Sausage  and  Shopping bags': 29,
#  'Beverages  and  Soda': 28,
#  'Bottled beer  and  Canned beer': 28,
#  'Canned beer  and  Newspapers': 28,
#  'Canned beer  and  Pastry': 28,
#  'Canned beer  and  Shopping bags': 28,
#  'Chocolate  and  Other vegetables': 28,
#  'Cream cheese   and  Rolls/buns': 28,
#  'Curd  and  Tropical fruit': 28,
#  'Hard cheese  and  Whole milk': 28,
#  'Margarine  and  Sausage': 28,
#  'Newspapers  and  Tropical fruit': 28,
#  'Pip fruit  and  Shopping bags': 28,
#  'Uht-milk  and  Rolls/buns': 27,
#  'Beef  and  Citrus fruit': 27,
#  'Beef  and  Soda': 27,
#  'Bottled water  and  Butter': 27,
#  'Bottled water  and  Newspapers': 27,
#  'Bottled water  and  Whipped/sour cream': 27,
#  'Brown bread  and  Sausage': 27,
#  'Chicken  and  Yogurt': 27,
#  'Citrus fruit  and  Shopping bags': 27,
#  'Domestic eggs  and  Sausage': 27,
#  'Frankfurter  and  Pip fruit': 27,
#  'Fruit/vegetable juice  and  Root vegetables': 27,
#  'Fruit/vegetable juice  and  Sausage': 27,
#  'Newspapers  and  Sausage': 27,
#  'Newspapers  and  Shopping bags': 27,
#  'Oil  and  Other vegetables': 27,
#  'Oil  and  Soda': 27,
#  'Beverages  and  Other vegetables': 26,
#  'Bottled beer  and  Newspapers': 26,
#  'Brown bread  and  Citrus fruit': 26,
#  'Frankfurter  and  Citrus fruit': 26,
#  'Frankfurter  and  Pastry': 26,
#  'Hygiene articles  and  Whole milk': 26,
#  'Ice cream  and  Rolls/buns': 26,
#  'Napkins  and  Pastry': 26,
#  'Napkins  and  Rolls/buns': 26,
#  'Napkins  and  Yogurt': 26,
#  'Onions  and  Rolls/buns': 26,
#  'Other vegetables  and  Waffles': 26,
#  'Pork  and  Root vegetables': 26,
#  'Beef  and  Newspapers': 25,
#  'Beef  and  Root vegetables': 25,
#  'Berries  and  Rolls/buns': 25,
#  'Bottled beer  and  Butter': 25,
#  'Bottled beer  and  Citrus fruit': 25,
#  'Bottled beer  and  Domestic eggs': 25,
#  'Bottled beer  and  Frankfurter': 25,
#  'Bottled beer  and  Fruit/vegetable juice': 25,
#  'Brown bread  and  Pip fruit': 25,
#  'Brown bread  and  Pork': 25,
#  'Butter milk  and  Whole milk': 25,
#  'Canned beer  and  Pork': 25,
#  'Cat food  and  Whole milk': 25,
#  'Chocolate  and  Soda': 25,
#  'Curd  and  Whipped/sour cream': 25,
#  'Hamburger meat  and  Soda': 25,
#  'Hamburger meat  and  Yogurt': 25,
#  'Hard cheese  and  Other vegetables': 25,
#  'Hard cheese  and  Rolls/buns': 25,
#  'Long life bakery product  and  Rolls/buns': 25,
#  'Other vegetables  and  Specialty bar': 25,
#  'Other vegetables  and  Specialty chocolate': 25,
#  'Pip fruit  and  Whipped/sour cream': 25,
#  'Semi-finished bread  and  Whole milk': 25,
#  'Specialty bar  and  Whole milk': 25,
#  'Whole milk  and  Chewing gum': 25,
#  'Beef  and  Rolls/buns': 24,
#  'Canned beer  and  Pip fruit': 24,
#  'Chocolate  and  Yogurt': 24,
#  'Citrus fruit  and  Frozen vegetables': 24,
#  'Cream cheese   and  Root vegetables': 24,
#  'Cream cheese   and  Yogurt': 24,
#  'Frankfurter  and  Margarine': 24,
#  'Grapes  and  Other vegetables': 24,
#  'Ham  and  Other vegetables': 24,
#  'Pip fruit  and  Pork': 24,
#  'Rolls/buns  and  Waffles': 24,
#  'Uht-milk  and  Tropical fruit': 23,
#  'Beef  and  Brown bread': 23,
#  'Beverages  and  Sausage': 23,
#  'Bottled beer  and  Brown bread': 23,
#  'Bottled beer  and  Pip fruit': 23,
#  'Bottled water  and  Brown bread': 23,
#  'Bottled water  and  Coffee': 23,
#  'Brown bread  and  Frankfurter': 23,
#  'Butter  and  Pastry': 23,
#  'Butter  and  Tropical fruit': 23,
#  'Canned beer  and  Citrus fruit': 23,
#  'Canned beer  and  Fruit/vegetable juice': 23,
#  'Canned beer  and  Whipped/sour cream': 23,
#  'Canned beer  and  White bread': 23,
#  'Coffee  and  Tropical fruit': 23,
#  'Domestic eggs  and  Newspapers': 23,
#  'Frankfurter  and  Shopping bags': 23,
#  'Frozen meals  and  Soda': 23,
#  'Napkins  and  Soda': 23,
#  'Newspapers  and  Whipped/sour cream': 23,
#  'Onions  and  Other vegetables': 23,
#  'Pastry  and  Pork': 23,
#  'Pastry  and  Whipped/sour cream': 23,
#  'Pork  and  Sausage': 23,
#  'Pork  and  Shopping bags': 23,
#  'Pork  and  Tropical fruit': 23,
#  'Salty snack  and  Yogurt': 23,
#  'Soda  and  White bread': 23,
#  'Berries  and  Soda': 22,
#  'Bottled beer  and  Shopping bags': 22,
#  'Bottled water  and  Canned beer': 22,
#  'Bottled water  and  Sugar': 22,
#  'Brown bread  and  Tropical fruit': 22,
#  'Candy  and  Rolls/buns': 22,
#  'Citrus fruit  and  Pip fruit': 22,
#  'Coffee  and  Frankfurter': 22,
#  'Cream cheese   and  Soda': 22,
#  'Curd  and  Root vegetables': 22,
#  'Dessert  and  Sausage': 22,
#  'Dessert  and  Soda': 22,
#  'Domestic eggs  and  Shopping bags': 22,
#  'Frankfurter  and  Sausage': 22,
#  'Frankfurter  and  Whipped/sour cream': 22,
#  'Frozen meals  and  Rolls/buns': 22,
#  'Fruit/vegetable juice  and  Pastry': 22,
#  'Margarine  and  Tropical fruit': 22,
#  'Onions  and  Soda': 22,
#  'Processed cheese  and  Rolls/buns': 22,
#  'Processed cheese  and  Whole milk': 22,
#  'Sliced cheese  and  Whole milk': 22,
#  'Beef  and  Margarine': 21,
#  'Beef  and  Whipped/sour cream': 21,
#  'Berries  and  Yogurt': 21,
#  'Bottled beer  and  Frozen vegetables': 21,
#  'Bottled water  and  Chocolate': 21,
#  'Bottled water  and  Margarine': 21,
#  'Bottled water  and  Pork': 21,
#  'Butter  and  Fruit/vegetable juice': 21,
#  'Butter  and  Margarine': 21,
#  'Butter  and  Newspapers': 21,
#  'Chewing gum  and  Yogurt': 21,
#  'Chicken  and  Tropical fruit': 21,
#  'Chocolate  and  Sausage': 21,
#  'Chocolate  and  Tropical fruit': 21,
#  'Citrus fruit  and  Napkins': 21,
#  'Citrus fruit  and  Specialty chocolate': 21,
#  'Coffee  and  Domestic eggs': 21,
#  'Coffee  and  Pastry': 21,
#  'Coffee  and  Shopping bags': 21,
#  'Cream cheese   and  Tropical fruit': 21,
#  'Curd  and  Pastry': 21,
#  'Detergent  and  Whole milk': 21,
#  'Domestic eggs  and  Frankfurter': 21,
#  'Frankfurter  and  Butter': 21,
#  'Fruit/vegetable juice  and  Pip fruit': 21,
#  'Grapes  and  Soda': 21,
#  'Hygiene articles  and  Other vegetables': 21,
#  'Misc. beverages  and  Whole milk': 21,
#  'Other vegetables  and  Sliced cheese': 21,
#  'Salty snack  and  Soda': 21,
#  'Sausage  and  White bread': 21,
#  'Soda  and  Butter milk': 21,
#  'Soda  and  Specialty chocolate': 21,
#  'Beef  and  Bottled water': 20,
#  'Bottled water  and  Chicken': 20,
#  'Brown bread  and  Root vegetables': 20,
#  'Butter  and  Shopping bags': 20,
#  'Canned beer  and  Frankfurter': 20,
#  'Canned beer  and  Frozen vegetables': 20,
#  'Chocolate  and  Pip fruit': 20,
#  'Citrus fruit  and  Coffee': 20,
#  'Citrus fruit  and  Fruit/vegetable juice': 20,
#  'Citrus fruit  and  Pork': 20,
#  'Curd  and  Frankfurter': 20,
#  'Curd  and  Pip fruit': 20,
#  'Domestic eggs  and  Pastry': 20,
#  'Flour  and  Whole milk': 20,
#  'Frankfurter  and  Tropical fruit': 20,
#  'Frozen meals  and  Yogurt': 20,
#  'Frozen vegetables  and  Pip fruit': 20,
#  'Hamburger meat  and  Tropical fruit': 20,
#  'Hygiene articles  and  Rolls/buns': 20,
#  'Long life bakery product  and  Soda': 20,
#  'Margarine  and  Pastry': 20,
#  'Margarine  and  Pork': 20,
#  'Meat  and  Rolls/buns': 20,
#  'Meat  and  Root vegetables': 20,
#  'Misc. beverages  and  Rolls/buns': 20,
#  'Oil  and  Rolls/buns': 20,
#  'Onions  and  Root vegetables': 20,
#  'Pastry  and  Shopping bags': 20,
#  'Red/blush wine  and  Rolls/buns': 20,
#  'Root vegetables  and  Waffles': 20,
#  'Sausage  and  Coffee': 20,
#  'Specialty chocolate  and  Tropical fruit': 20,
#  'Specialty chocolate  and  Whole milk': 20,
#  'Uht-milk  and  Soda': 19,
#  'Beef  and  Curd': 19,
#  'Beef  and  Frozen vegetables': 19,
#  'Beef  and  Shopping bags': 19,
#  'Berries  and  Tropical fruit': 19,
#  'Bottled water  and  White bread': 19,
#  'Brown bread  and  Shopping bags': 19,
#  'Butter milk  and  Other vegetables': 19,
#  'Butter milk  and  Rolls/buns': 19,
#  'Butter milk  and  Yogurt': 19,
#  'Candy  and  Soda': 19,
#  'Chicken  and  Pastry': 19,
#  'Chicken  and  Shopping bags': 19,
#  'Chicken  and  Whipped/sour cream': 19,
#  'Citrus fruit  and  Domestic eggs': 19,
#  'Curd  and  Shopping bags': 19,
#  'Frozen meals  and  Sausage': 19,
#  'Ham  and  Rolls/buns': 19,
#  'Ham  and  Yogurt': 19,
#  'Hamburger meat  and  Root vegetables': 19,
#  'Hard cheese  and  Yogurt': 19,
#  'Ice cream  and  Other vegetables': 19,
#  'Margarine  and  Pip fruit': 19,
#  'Misc. beverages  and  Yogurt': 19,
#  'Newspapers  and  Pip fruit': 19,
#  'Onions  and  Yogurt': 19,
#  'Other vegetables  and  Sugar': 19,
#  'Rolls/buns  and  Specialty chocolate': 19,
#  'Root vegetables  and  White bread': 19,
#  'Soda  and  Specialty bar': 19,
#  'Soft cheese  and  Yogurt': 19,
#  'Tropical fruit  and  Napkins': 19,
#  'White wine  and  Whole milk': 19,
#  'Beef  and  Pastry': 18,
#  'Beverages  and  Rolls/buns': 18,
#  'Bottled beer  and  Whipped/sour cream': 18,
#  'Bottled water  and  Fruit/vegetable juice': 18,
#  'Brown bread  and  Curd': 18,
#  'Brown bread  and  Domestic eggs': 18,
#  'Candy  and  Yogurt': 18,
#  'Canned beer  and  Curd': 18,
#  'Canned beer  and  Domestic eggs': 18,
#  'Canned beer  and  Margarine': 18,
#  'Chicken  and  Citrus fruit': 18,
#  'Chocolate  and  Root vegetables': 18,
#  'Citrus fruit  and  Newspapers': 18,
#  'Citrus fruit  and  Sausage': 18,
#  'Cream cheese   and  Sausage': 18,
#  'Dessert  and  Yogurt': 18,
#  'Domestic eggs  and  Pork': 18,
#  'Grapes  and  Rolls/buns': 18,
#  'Ham  and  Soda': 18,
#  'Ice cream  and  Soda': 18,
#  'Long life bakery product  and  Yogurt': 18,
#  'Misc. beverages  and  Other vegetables': 18,
#  'Onions  and  Tropical fruit': 18,
#  'Other vegetables  and  Soft cheese': 18,
#  'Packaged fruit/vegetables  and  Rolls/buns': 18,
#  'Rolls/buns  and  Specialty bar': 18,
#  'Root vegetables  and  Sliced cheese': 18,
#  'Shopping bags  and  Cream cheese ': 18,
#  'Shopping bags  and  Dessert': 18,
#  'Shopping bags  and  Whipped/sour cream': 18,
#  'Soda  and  Sugar': 18,
#  'Specialty bar  and  Yogurt': 18,
#  'Whole milk  and  Soft cheese': 18,
#  'Uht-milk  and  Sausage': 17,
#  'Beef  and  Butter': 17,
#  'Beef  and  Domestic eggs': 17,
#  'Beef  and  Tropical fruit': 17,
#  'Berries  and  Pip fruit': 17,
#  'Bottled beer  and  Curd': 17,
#  'Butter  and  Pip fruit': 17,
#  'Butter  and  Whipped/sour cream': 17,
#  'Candy  and  Other vegetables': 17,
#  'Canned beer  and  Chicken': 17,
#  'Chicken  and  Curd': 17,
#  'Citrus fruit  and  Curd': 17,
#  'Citrus fruit  and  White bread': 17,
#  'Curd  and  Pork': 17,
#  'Frankfurter  and  Fruit/vegetable juice': 17,
#  'Ham  and  Tropical fruit': 17,
#  'Herbs  and  Whole milk': 17,
#  'Long life bakery product  and  Other vegetables': 17,
#  'Margarine  and  Citrus fruit': 17,
#  'Margarine  and  Whipped/sour cream': 17,
#  'Other vegetables  and  Red/blush wine': 17,
#  'Salty snack  and  Sausage': 17,
#  'Sausage  and  Sliced cheese': 17,
#  'Sliced cheese  and  Soda': 17,
#  'Tropical fruit  and  Waffles': 17,
#  'Waffles  and  Yogurt': 17,
#  'Yogurt  and  Uht-milk': 17,
#  'Yogurt  and  Herbs': 17,
#  'Uht-milk  and  Bottled water': 16,
#  'Beef  and  Bottled beer': 16,
#  'Beef  and  Fruit/vegetable juice': 16,
#  'Berries  and  Bottled water': 16,
#  'Berries  and  Pastry': 16,
#  'Berries  and  Root vegetables': 16,
#  'Beverages  and  Bottled water': 16,
#  'Bottled beer  and  Hamburger meat': 16,
#  'Bottled beer  and  Margarine': 16,
#  'Bottled beer  and  Pork': 16,
#  'Bottled water  and  Dessert': 16,
#  'Bottled water  and  Frozen vegetables': 16,
#  'Brown bread  and  Whipped/sour cream': 16,
#  'Canned beer  and  Chocolate': 16,
#  'Cat food  and  Rolls/buns': 16,
#  'Chewing gum  and  Other vegetables': 16,
#  'Chicken  and  Pip fruit': 16,
#  'Chicken  and  Sausage': 16,
#  'Chocolate  and  Citrus fruit': 16,
#  'Coffee  and  Pip fruit': 16,
#  'Dessert  and  Root vegetables': 16,
#  'Dessert  and  Tropical fruit': 16,
#  'Detergent  and  Yogurt': 16,
#  'Domestic eggs  and  Fruit/vegetable juice': 16,
#  'Flour  and  Tropical fruit': 16,
#  'Frankfurter  and  Frozen vegetables': 16,
#  'Frankfurter  and  Newspapers': 16,
#  'Frozen fish  and  Whole milk': 16,
#  'Frozen vegetables  and  Tropical fruit': 16,
#  'Grapes  and  Root vegetables': 16,
#  'Grapes  and  Sausage': 16,
#  'Hard cheese  and  Pip fruit': 16,
#  'Hygiene articles  and  Soda': 16,
#  'Long life bakery product  and  Sausage': 16,
#  'Margarine  and  Curd': 16,
#  'Misc. beverages  and  Sausage': 16,
#  'Napkins  and  Root vegetables': 16,
#  'Oil  and  Yogurt': 16,
#  'Onions  and  Whipped/sour cream': 16,
#  'Pasta  and  Whole milk': 16,
#  'Processed cheese  and  Root vegetables': 16,
#  'Root vegetables  and  Salty snack': 16,
#  'Tropical fruit  and  Long life bakery product': 16,
#  'Yogurt  and  White bread': 16,
#  'Uht-milk  and  Root vegetables': 15,
#  'Beef  and  Canned beer': 15,
#  'Bottled beer  and  Chicken': 15,
#  'Bottled beer  and  Chocolate': 15,
#  'Bottled water  and  Onions': 15,
#  'Brown bread  and  Butter': 15,
#  'Brown bread  and  White bread': 15,
#  'Butter  and  Canned beer': 15,
#  'Butter milk  and  Root vegetables': 15,
#  'Butter milk  and  Shopping bags': 15,
#  'Butter milk  and  Tropical fruit': 15,
#  'Candy  and  Citrus fruit': 15,
#  'Canned beer  and  Coffee': 15,
#  'Canned beer  and  Salty snack': 15,
#  'Cat food  and  Tropical fruit': 15,
#  'Chewing gum  and  Soda': 15,
#  'Chicken  and  Domestic eggs': 15,
#  'Chicken  and  Margarine': 15,
#  'Chicken  and  Root vegetables': 15,
#  'Citrus fruit  and  Cream cheese ': 15,
#  'Cream cheese   and  Frankfurter': 15,
#  'Curd  and  Dessert': 15,
#  'Frankfurter  and  Beef': 15,
#  'Fruit/vegetable juice  and  Margarine': 15,
#  'Hygiene articles  and  Root vegetables': 15,
#  'Margarine  and  Shopping bags': 15,
#  'Meat  and  Soda': 15,
#  'Other vegetables  and  Pot plants': 15,
#  'Other vegetables  and  Semi-finished bread': 15,
#  'Pastry  and  Hamburger meat': 15,
#  'Pickled vegetables  and  Whole milk': 15,
#  'Pot plants  and  Whole milk': 15,
#  'Rolls/buns  and  Detergent': 15,
#  'Rolls/buns  and  Seasonal products': 15,
#  'Rolls/buns  and  Soft cheese': 15,
#  'Root vegetables  and  Hard cheese': 15,
#  'Root vegetables  and  Misc. beverages': 15,
#  'Salty snack  and  Tropical fruit': 15,
#  'Tropical fruit  and  Sugar': 15,
#  'Whipped/sour cream  and  White bread': 15,
#  'White bread  and  Domestic eggs': 15,
#  'White bread  and  Tropical fruit': 15,
#  'Uht-milk  and  Bottled beer': 14,
#  'Uht-milk  and  Frankfurter': 14,
#  'Uht-milk  and  Pastry': 14,
#  'Beef  and  Coffee': 14,
#  'Beef  and  Pork': 14,
#  'Beverages  and  Yogurt': 14,
#  'Bottled beer  and  Coffee': 14,
#  'Bottled beer  and  Oil': 14,
#  'Bottled water  and  Cream cheese ': 14,
#  'Bottled water  and  Napkins': 14,
#  'Bottled water  and  Specialty bar': 14,
#  'Brown bread  and  Chocolate': 14,
#  'Brown bread  and  Frozen vegetables': 14,
#  'Brown bread  and  Fruit/vegetable juice': 14,
#  'Brown bread  and  Newspapers': 14,
#  'Butter milk  and  Citrus fruit': 14,
#  'Canned beer  and  Dessert': 14,
#  'Canned beer  and  Onions': 14,
#  'Canned fish  and  Whole milk': 14,
#  'Canned vegetables  and  Whole milk': 14,
#  'Citrus fruit  and  Specialty bar': 14,
#  'Citrus fruit  and  Waffles': 14,
#  'Coffee  and  Newspapers': 14,
#  'Curd  and  Domestic eggs': 14,
#  'Dishes  and  Other vegetables': 14,
#  'Frankfurter  and  Napkins': 14,
#  'Frozen dessert  and  Whole milk': 14,
#  'Frozen vegetables  and  Pastry': 14,
#  'Hamburger meat  and  Newspapers': 14,
#  'Hard cheese  and  Bottled water': 14,
#  'Hard cheese  and  Soda': 14,
#  'Hygiene articles  and  Yogurt': 14,
#  'Ice cream  and  Yogurt': 14,
#  'Meat  and  Pip fruit': 14,
#  'Meat  and  Yogurt': 14,
#  'Mustard  and  Whole milk': 14,
#  'Napkins  and  Newspapers': 14,
#  'Napkins  and  Pork': 14,
#  'Newspapers  and  White bread': 14,
#  'Pasta  and  Yogurt': 14,
#  'Pastry  and  Sliced cheese': 14,
#  'Pip fruit  and  White bread': 14,
#  'Pork  and  Newspapers': 14,
#  'Pork  and  Whipped/sour cream': 14,
#  'Rolls/buns  and  Canned fish': 14,
#  'Rolls/buns  and  Sliced cheese': 14,
#  'Salty snack  and  Brown bread': 14,
#  'Shopping bags  and  Waffles': 14,
#  'Soda  and  Waffles': 14,
#  'Soda  and  White wine': 14,
#  'Specialty chocolate  and  Root vegetables': 14,
#  'Spread cheese  and  Whole milk': 14,
#  'Whole milk  and  Dishes': 14,
#  'Yogurt  and  Grapes': 14,
#  'Yogurt  and  Sliced cheese': 14,
#  'Uht-milk  and  Cream cheese ': 13,
#  'Uht-milk  and  Pip fruit': 13,
#  'Baking powder  and  Whole milk': 13,
#  'Beef  and  Chocolate': 13,
#  'Beef  and  Pip fruit': 13,
#  'Beef  and  Sausage': 13,
#  'Beef  and  Waffles': 13,
#  'Beef  and  White bread': 13,
#  'Berries  and  Bottled beer': 13,
#  'Berries  and  Fruit/vegetable juice': 13,
#  'Berries  and  Sausage': 13,
#  'Bottled beer  and  Frozen meals': 13,
#  'Brown bread  and  Ham': 13,
#  'Butter  and  Chocolate': 13,
#  'Butter  and  Coffee': 13,
#  'Chewing gum  and  Pastry': 13,
#  'Chewing gum  and  Rolls/buns': 13,
#  'Chocolate  and  Shopping bags': 13,
#  'Citrus fruit  and  Ham': 13,
#  'Coffee  and  Hamburger meat': 13,
#  'Coffee  and  Whipped/sour cream': 13,
#  'Condensed milk  and  Whole milk': 13,
#  'Cream cheese   and  Frozen vegetables': 13,
#  'Dessert  and  Citrus fruit': 13,
#  'Domestic eggs  and  Pip fruit': 13,
#  'Domestic eggs  and  Waffles': 13,
#  'Domestic eggs  and  Whipped/sour cream': 13,
#  'Finished products  and  Whole milk': 13,
#  'Flour  and  Soda': 13,
#  'Fruit/vegetable juice  and  Pork': 13,
#  'Fruit/vegetable juice  and  Whipped/sour cream': 13,
#  'Grapes  and  Tropical fruit': 13,
#  'Hamburger meat  and  Sausage': 13,
#  'Hamburger meat  and  Whipped/sour cream': 13,
#  'Herbs  and  Rolls/buns': 13,
#  'Hygiene articles  and  Sausage': 13,
#  'Long life bakery product  and  Pork': 13,
#  'Margarine  and  Brown bread': 13,
#  'Margarine  and  Newspapers': 13,
#  'Meat  and  Tropical fruit': 13,
#  'Napkins  and  Sausage': 13,
#  'Napkins  and  Shopping bags': 13,
#  'Oil  and  Pork': 13,
#  'Onions  and  Pastry': 13,
#  'Other vegetables  and  Herbs': 13,
#  'Red/blush wine  and  Soda': 13,
#  'Red/blush wine  and  Whole milk': 13,
#  'Rolls/buns  and  Sugar': 13,
#  'Root vegetables  and  Sugar': 13,
#  'Salty snack  and  Shopping bags': 13,
#  'Semi-finished bread  and  Yogurt': 13,
#  'Shopping bags  and  Hard cheese': 13,
#  'Shopping bags  and  White bread': 13,
#  'Soda  and  Semi-finished bread': 13,
#  'Specialty bar  and  Tropical fruit': 13,
#  'White wine  and  Pip fruit': 13,
#  'Whole milk  and  Brandy': 13,
#  'Whole milk  and  Dish cleaner': 13,
#  'Yogurt  and  Pot plants': 13,
#  'Yogurt  and  Sugar': 13,
#  'Berries  and  Butter': 12,
#  'Bottled beer  and  Cat food': 12,
#  'Bottled beer  and  White bread': 12,
#  'Bottled water  and  Frozen meals': 12,
#  'Bottled water  and  Hamburger meat': 12,
#  'Bottled water  and  Meat': 12,
#  'Brown bread  and  Chicken': 12,
#  'Brown bread  and  Coffee': 12,
#  'Butter  and  Chicken': 12,
#  'Butter  and  Domestic eggs': 12,
#  'Butter  and  Pork': 12,
#  'Candy  and  Tropical fruit': 12,
#  'Canned beer  and  Butter milk': 12,
#  'Canned beer  and  Ham': 12,
#  'Canned beer  and  Ice cream': 12,
#  'Canned beer  and  Specialty chocolate': 12,
#  'Cat food  and  Soda': 12,
#  'Chicken  and  Coffee': 12,
#  'Chicken  and  Onions': 12,
#  'Chicken  and  Waffles': 12,
#  'Chocolate  and  Domestic eggs': 12,
#  'Citrus fruit  and  Uht-milk': 12,
#  'Coffee  and  Margarine': 12,
#  'Coffee  and  Sugar': 12,
#  'Cream cheese   and  Whipped/sour cream': 12,
#  'Dessert  and  Domestic eggs': 12,
#  'Dessert  and  Pastry': 12,
#  'Domestic eggs  and  Margarine': 12,
#  'Frozen meals  and  Root vegetables': 12,
#  'Frozen vegetables  and  Fruit/vegetable juice': 12,
#  'Ham  and  Pastry': 12,
#  'Hamburger meat  and  Margarine': 12,
#  'Hard cheese  and  Tropical fruit': 12,
#  'Hygiene articles  and  Tropical fruit': 12,
#  'Liquor  and  Other vegetables': 12,
#  'Long life bakery product  and  Root vegetables': 12,
#  'Meat  and  Whipped/sour cream': 12,
#  'Misc. beverages  and  Soda': 12,
#  'Newspapers  and  Chewing gum': 12,
#  'Newspapers  and  Fruit/vegetable juice': 12,
#  'Newspapers  and  Salty snack': 12,
#  'Onions  and  Pip fruit': 12,
#  'Onions  and  Sausage': 12,
#  'Pickled vegetables  and  Rolls/buns': 12,
#  'Pip fruit  and  Dessert': 12,
#  'Pip fruit  and  Salty snack': 12,
#  'Sausage  and  Waffles': 12,
#  'Sausage  and  White wine': 12,
#  'Soda  and  Pasta': 12,
#  'Soda  and  Pickled vegetables': 12,
#  'Soda  and  Soft cheese': 12,
#  'Sugar  and  Bottled beer': 12,
#  'Sugar  and  Citrus fruit': 12,
#  'Tropical fruit  and  Frozen meals': 12,
#  'White bread  and  Pastry': 12,
#  'Uht-milk  and  Pork': 11,
#  'Uht-milk  and  Shopping bags': 11,
#  'Beef  and  Berries': 11,
#  'Beef  and  Butter milk': 11,
#  'Berries  and  Coffee': 11,
#  'Beverages  and  Root vegetables': 11,
#  'Bottled beer  and  Hard cheese': 11,
#  'Bottled beer  and  Hygiene articles': 11,
#  'Bottled water  and  Butter milk': 11,
#  'Bottled water  and  Flour': 11,
#  'Bottled water  and  Grapes': 11,
#  'Bottled water  and  Salty snack': 11,
#  'Bottled water  and  Waffles': 11,
#  'Brown bread  and  Dessert': 11,
#  'Brown bread  and  Hamburger meat': 11,
#  'Brown bread  and  Waffles': 11,
#  'Butter  and  Butter milk': 11,
#  'Butter  and  Curd': 11,
#  'Butter  and  Frozen vegetables': 11,
#  'Cake bar  and  Whole milk': 11,
#  'Candles  and  Whole milk': 11,
#  'Canned beer  and  Cream cheese ': 11,
#  'Canned beer  and  Dishes': 11,
#  'Canned beer  and  Hygiene articles': 11,
#  'Canned fish  and  Yogurt': 11,
#  'Cat food  and  Citrus fruit': 11,
#  'Cat food  and  Fruit/vegetable juice': 11,
#  'Cat food  and  Other vegetables': 11,
#  'Chewing gum  and  Sausage': 11,
#  'Chicken  and  Fruit/vegetable juice': 11,
#  'Chicken  and  White bread': 11,
#  'Chocolate  and  Frankfurter': 11,
#  'Chocolate  and  Margarine': 11,
#  'Chocolate  and  Pastry': 11,
#  'Citrus fruit  and  Hamburger meat': 11,
#  'Citrus fruit  and  Hard cheese': 11,
#  'Citrus fruit  and  Long life bakery product': 11,
#  'Citrus fruit  and  Oil': 11,
#  'Coffee  and  Fruit/vegetable juice': 11,
#  'Coffee  and  Misc. beverages': 11,
#  'Coffee  and  Napkins': 11,
#  'Condensed milk  and  Other vegetables': 11,
#  'Curd  and  Frozen meals': 11,
#  'Dessert  and  Fruit/vegetable juice': 11,
#  'Dessert  and  Pork': 11,
#  'Detergent  and  Sausage': 11,
#  'Detergent  and  Tropical fruit': 11,
#  'Domestic eggs  and  Frozen vegetables': 11,
#  'Domestic eggs  and  Hamburger meat': 11,
#  'Domestic eggs  and  Meat': 11,
#  'Frankfurter  and  White bread': 11,
#  'Frozen fish  and  Tropical fruit': 11,
#  'Frozen vegetables  and  Curd': 11,
#  'Frozen vegetables  and  Pork': 11,
#  'Grapes  and  Whipped/sour cream': 11,
#  'Hamburger meat  and  Pork': 11,
#  'Hard cheese  and  Sausage': 11,
#  'House keeping products  and  Whole milk': 11,
#  'Hygiene articles  and  Pastry': 11,
#  'Ice cream  and  Root vegetables': 11,
#  'Long life bakery product  and  Pastry': 11,
#  'Misc. beverages  and  Bottled beer': 11,
#  'Napkins  and  Brown bread': 11,
#  'Napkins  and  Pip fruit': 11,
#  'Newspapers  and  Dessert': 11,
#  'Oil  and  Sausage': 11,
#  'Oil  and  Tropical fruit': 11,
#  'Oil  and  Whipped/sour cream': 11,
#  'Other vegetables  and  Spread cheese': 11,
#  'Pasta  and  Sausage': 11,
#  'Pip fruit  and  Beverages': 11,
#  'Pork  and  Frankfurter': 11,
#  'Processed cheese  and  Bottled water': 11,
#  'Rolls/buns  and  Condensed milk': 11,
#  'Rolls/buns  and  Dishes': 11,
#  'Rolls/buns  and  Flour': 11,
#  'Rolls/buns  and  Semi-finished bread': 11,
#  'Rolls/buns  and  White wine': 11,
#  'Sausage  and  Sugar': 11,
#  'Semi-finished bread  and  Tropical fruit': 11,
#  'Shopping bags  and  Sliced cheese': 11,
#  'Sweet spreads  and  Tropical fruit': 11,
#  'Turkey  and  Whole milk': 11,
#  'Waffles  and  Curd': 11,
#  'Waffles  and  Pip fruit': 11,
#  'Whipped/sour cream  and  Waffles': 11,
#  'Whole milk  and  Pet care': 11,
#  'Baking powder  and  Yogurt': 10,
#  'Beef  and  Frozen meals': 10,
#  'Beef  and  Long life bakery product': 10,
#  'Beef  and  Misc. beverages': 10,
#  'Beef  and  Salty snack': 10,
#  'Beef  and  Specialty chocolate': 10,
#  'Berries  and  Canned beer': 10,
#  'Berries  and  Newspapers': 10,
#  'Berries  and  Whipped/sour cream': 10,
#  'Berries  and  White bread': 10,
#  'Beverages  and  Curd': 10,
#  'Beverages  and  Tropical fruit': 10,
#  'Bottled beer  and  Ice cream': 10,
#  'Bottled beer  and  Onions': 10,
#  'Bottled water  and  Ham': 10,
#  'Bottled water  and  Hygiene articles': 10,
#  'Bottled water  and  Long life bakery product': 10,
#  'Brown bread  and  Butter milk': 10,
#  'Butter  and  Dessert': 10,
#  'Butter  and  Ice cream': 10,
#  'Butter  and  Long life bakery product': 10,
#  'Butter milk  and  Long life bakery product': 10,
#  'Butter milk  and  Margarine': 10,
#  'Cake bar  and  Sausage': 10,
#  'Candy  and  Bottled beer': 10,
#  'Canned beer  and  Frozen meals': 10,
#  'Canned beer  and  Long life bakery product': 10,
#  'Canned beer  and  Napkins': 10,
#  'Canned beer  and  Specialty bar': 10,
#  'Canned beer  and  Sugar': 10,
#  'Chewing gum  and  Citrus fruit': 10,
#  'Chicken  and  Hygiene articles': 10,
#  'Citrus fruit  and  Ice cream': 10,
#  'Citrus fruit  and  Onions': 10,
#  'Citrus fruit  and  Salty snack': 10,
#  'Citrus fruit  and  White wine': 10,
#  'Cling film/bags  and  Whole milk': 10,
#  'Coffee  and  Frozen vegetables': 10,
#  'Cream cheese   and  Curd': 10,
#  'Cream cheese   and  Fruit/vegetable juice': 10,
#  'Cream cheese   and  Onions': 10,
#  'Curd  and  Coffee': 10,
#  'Curd  and  Fruit/vegetable juice': 10,
#  'Curd  and  Hamburger meat': 10,
#  'Curd  and  Meat': 10,
#  'Curd  and  Newspapers': 10,
#  'Dessert  and  Margarine': 10,
#  'Detergent  and  Soda': 10,
#  'Dishes  and  Pastry': 10,
#  'Dishes  and  Soda': 10,
#  'Frankfurter  and  Hamburger meat': 10,
#  'Frankfurter  and  Long life bakery product': 10,
#  'Fruit/vegetable juice  and  Chocolate': 10,
#  'Fruit/vegetable juice  and  Long life bakery product': 10,
#  'Fruit/vegetable juice  and  Shopping bags': 10,
#  'Grapes  and  Bottled beer': 10,
#  'Grapes  and  Pastry': 10,
#  'Ham  and  Whipped/sour cream': 10,
#  'Hard cheese  and  Curd': 10,
#  'Hard cheese  and  Pastry': 10,
#  'Ice cream  and  Pip fruit': 10,
#  'Liquor  and  Whole milk': 10,
#  'Liquor (appetizer)  and  Soda': 10,
#  'Liquor (appetizer)  and  Whole milk': 10,
#  'Long life bakery product  and  Napkins': 10,
#  'Long life bakery product  and  Newspapers': 10,
#  'Margarine  and  Sugar': 10,
#  'Misc. beverages  and  Curd': 10,
#  'Misc. beverages  and  Frankfurter': 10,
#  'Misc. beverages  and  Pastry': 10,
#  'Oil  and  Root vegetables': 10,
#  'Other vegetables  and  Processed cheese': 10,
#  'Pasta  and  Pip fruit': 10,
#  'Pastry  and  Cream cheese ': 10,
#  'Pastry  and  Salty snack': 10,
#  'Pip fruit  and  Specialty chocolate': 10,
#  'Pork  and  Coffee': 10,
#  'Pork  and  Cream cheese ': 10,
#  'Pot plants  and  Rolls/buns': 10,
#  'Processed cheese  and  Yogurt': 10,
#  'Roll products   and  Whole milk': 10,
#  'Rolls/buns  and  Frozen fish': 10,
#  'Root vegetables  and  Chewing gum': 10,
#  'Root vegetables  and  Semi-finished bread': 10,
#  'Root vegetables  and  White wine': 10,
#  'Sausage  and  Specialty bar': 10,
#  'Seasonal products  and  Soda': 10,
#  'Seasonal products  and  Whole milk': 10,
#  'Shopping bags  and  Berries': 10,
#  'Shopping bags  and  Sugar': 10,
#  'Shopping bags  and  White wine': 10,
#  'Specialty bar  and  Root vegetables': 10,
#  'Whipped/sour cream  and  Flour': 10,
#  'Whole milk  and  Chocolate marshmallow': 10,
#  'Whole milk  and  Dog food': 10,
#  'Yogurt  and  Mustard': 10,
#  'Uht-milk  and  Canned beer': 9,
#  'Uht-milk  and  Chicken': 9,
#  'Uht-milk  and  Coffee': 9,
#  'Uht-milk  and  Frozen vegetables': 9,
#  'Uht-milk  and  Margarine': 9,
#  'Baking powder  and  Canned beer': 9,
#  'Beef  and  Chicken': 9,
#  'Beef  and  Ice cream': 9,
#  'Beef  and  Napkins': 9,
#  'Beverages  and  Canned beer': 9,
#  'Beverages  and  Domestic eggs': 9,
#  'Beverages  and  Fruit/vegetable juice': 9,
#  'Bottled beer  and  Butter milk': 9,
#  'Bottled beer  and  Dessert': 9,
#  'Bottled beer  and  Ham': 9,
#  'Bottled beer  and  Salty snack': 9,
#  'Bottled water  and  Turkey': 9,
#  'Butter  and  Candy': 9,
#  'Butter  and  Frozen meals': 9,
#  'Butter  and  Onions': 9,
#  'Butter milk  and  Uht-milk': 9,
#  'Candy  and  Domestic eggs': 9,
#  'Candy  and  Pastry': 9,
#  'Cat food  and  Newspapers': 9,
#  'Chicken  and  Frozen meals': 9,
#  'Chicken  and  Frozen vegetables': 9,
#  'Chocolate  and  Coffee': 9,
#  'Chocolate  and  Curd': 9,
#  'Chocolate  and  Whipped/sour cream': 9,
#  'Citrus fruit  and  Frozen meals': 9,
#  'Cling film/bags  and  Rolls/buns': 9,
#  'Coffee  and  Onions': 9,
#  'Cream cheese   and  Newspapers': 9,
#  'Cream cheese   and  Specialty chocolate': 9,
#  'Curd  and  Specialty chocolate': 9,
#  'Curd  and  Sugar': 9,
#  'Dessert  and  Hamburger meat': 9,
#  'Domestic eggs  and  Specialty bar': 9,
#  'Domestic eggs  and  Sugar': 9,
#  'Finished products  and  Other vegetables': 9,
#  'Finished products  and  Rolls/buns': 9,
#  'Flour  and  Yogurt': 9,
#  'Flower (seeds)  and  Whole milk': 9,
#  'Frankfurter  and  Hard cheese': 9,
#  'Frankfurter  and  Ice cream': 9,
#  'Frankfurter  and  Red/blush wine': 9,
#  'Frankfurter  and  Sliced cheese': 9,
#  'Frankfurter  and  Sugar': 9,
#  'Frozen dessert  and  Soda': 9,
#  'Frozen meals  and  Margarine': 9,
#  'Frozen meals  and  Pastry': 9,
#  'Frozen meals  and  Whipped/sour cream': 9,
#  'Frozen potato products  and  Whole milk': 9,
#  'Frozen vegetables  and  Margarine': 9,
#  'Frozen vegetables  and  Newspapers': 9,
#  ...}
